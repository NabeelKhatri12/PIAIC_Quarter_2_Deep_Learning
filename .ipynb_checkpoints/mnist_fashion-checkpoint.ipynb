# %%
import tensorflow as tf
from tensorflow.keras import datasets, models, layers

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.fashion_mnist.load_data()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0
model = models.Sequential([layers.Flatten(),
                          layers.Dense(512, activation = 'relu'),
                          layers.Dense(10, activation = 'softmax')])

# %%
model.compile(optimizer = 'Adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(train_images, train_labels, epochs = 5, batch_size = 128)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.5128 - accuracy: 0.8213
# Epoch 2/5
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.3779 - accuracy: 0.8645
# Epoch 3/5
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.3347 - accuracy: 0.8791
# Epoch 4/5
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.3089 - accuracy: 0.8867
# Epoch 5/5
# 60000/60000 [==============================] - 6s 95us/sample - loss: 0.2905 - accuracy: 0.8937

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.35152465611696243, 0.8715]
